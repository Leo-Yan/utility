# %% [markdown]
# # Summary plots

# %% [markdown]
# `trappy.summary_plots()` shows all the relevant (for the power allocator governor) plots for a particular run.

# %% [markdown]
# First some hacks to allow importing trappy from here

# %%
import sys
sys.path.append("..")

# %%
# %pylab inline
import trappy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# For a description of `map_label` and `actor_order` see the compare runs notebook.

# %%
map_label = {"00000000,0000000f": "cls0", "00000000,000000f0": "cls1"}
actor_order = ["cls0", "cls1"]

# %%
trappy.summary_plots(actor_order, map_label, path="/tmp/trace.txt")
